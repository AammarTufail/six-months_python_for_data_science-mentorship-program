# %% [markdown]
# # RNN (Recurent Neural Network) - LSTM (Long Short Term Memory) - GRU (Gated Recurent Unit)

# %% [markdown]
# # RNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN
from tensorflow.keras.models import Sequential

# Generate example data
X = np.random.rand(100, 10, 1)
y = np.random.randint(0, 2, size=(100,))

# Define the model
model = Sequential([
    SimpleRNN(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X, y, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# Epoch 1/10
# 4/4 [==============================] - 2s 186ms/step - loss: 0.7271 - accuracy: 0.4400
# Epoch 2/10
# 4/4 [==============================] - 0s 56ms/step - loss: 0.7031 - accuracy: 0.4700
# Epoch 3/10
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6924 - accuracy: 0.5100
# Epoch 4/10
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6863 - accuracy: 0.5200
# Epoch 5/10
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6814 - accuracy: 0.5600
# Epoch 6/10
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6766 - accuracy: 0.6000
# Epoch 7/10
# 4/4 [==============================] - 0s 70ms/step - loss: 0.6729 - accuracy: 0.5800
# Epoch 8/10
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6697 - accuracy: 0.5700
# Epoch 9/10
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6723 - accuracy: 0.5700
# Epoch 10/10
# 4/4 [==============================] - 0s 52ms/step - loss: 0.6727 - accuracy: 0.5700
# 4/4 [==============================] - 0s 30ms/step - loss: 0.6762 - accuracy: 0.5700
# Test Loss: 0.6761661767959595
# Test Accuracy: 0.5699999928474426

# %% [markdown]
# # LSTM (Long Short Term Memory) is a special kind of RNN, capable of learning long-term dependencies.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model
model = Sequential([
    LSTM(32, input_shape=(seq_length, 1)),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 29ms/step - loss: 0.8715
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7113
# Epoch 3/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5686
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4582
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3585
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2864
# Epoch 7/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2316
# Epoch 8/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1997
# Epoch 9/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1815
# Epoch 10/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1767
# Epoch 11/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1758
# Epoch 12/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1749
# Epoch 13/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1736
# Epoch 14/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1700
# Epoch 15/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1667
# Epoch 16/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1627
# Epoch 17/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1598
# Epoch 18/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1587
# Epoch 19/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1567
# Epoch 20/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1561
# Epoch 21/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1549
# Epoch 22/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1538
# Epoch 23/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1536
# Epoch 24/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1515
# Epoch 25/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1506
# Epoch 26/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1499
# Epoch 27/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1492
# Epoch 28/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1482
# Epoch 29/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1473
# Epoch 30/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1460
# Epoch 31/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1448
# Epoch 32/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1440
# Epoch 33/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1425
# Epoch 34/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1415
# Epoch 35/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1406
# Epoch 36/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1390
# Epoch 37/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1383
# Epoch 38/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1368
# Epoch 39/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1372
# Epoch 40/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1359
# Epoch 41/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1358
# Epoch 42/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1325
# Epoch 43/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1329
# Epoch 44/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1323
# Epoch 45/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1311
# Epoch 46/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1290
# Epoch 47/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1292
# Epoch 48/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1272
# Epoch 49/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1233
# Epoch 50/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1222
# Epoch 51/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1216
# Epoch 52/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1205
# Epoch 53/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1166
# Epoch 54/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1160
# Epoch 55/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1147
# Epoch 56/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1104
# Epoch 57/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1076
# Epoch 58/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1061
# Epoch 59/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1037
# Epoch 60/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1014
# Epoch 61/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0995
# Epoch 62/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0972
# Epoch 63/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0956
# Epoch 64/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0955
# Epoch 65/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0921
# Epoch 66/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0930
# Epoch 67/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0905
# Epoch 68/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0859
# Epoch 69/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0831
# Epoch 70/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0790
# Epoch 71/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0839
# Epoch 72/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0781
# Epoch 73/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0802
# Epoch 74/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0744
# Epoch 75/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0714
# Epoch 76/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0699
# Epoch 77/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0736
# Epoch 78/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0655
# Epoch 79/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0720
# Epoch 80/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0637
# Epoch 81/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0779
# Epoch 82/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0653
# Epoch 83/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0640
# Epoch 84/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0632
# Epoch 85/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0580
# Epoch 86/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0572
# Epoch 87/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0563
# Epoch 88/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0550
# Epoch 89/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0544
# Epoch 90/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0534
# Epoch 91/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0528
# Epoch 92/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0511
# Epoch 93/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0506
# Epoch 94/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0515
# Epoch 95/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0496
# Epoch 96/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0486
# Epoch 97/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0470
# Epoch 98/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0471
# Epoch 99/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0481
# Epoch 100/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0493
# 1/1 [==============================] - 0s 198ms/step - loss: 2.0215
# Test Loss: 2.0215187072753906
# 1/1 [==============================] - 0s 178ms/step

# %% [markdown]
# # let's build a simple RNN-based character-level text generator using a sample text. We'll use a sequence-to-sequence prediction approach to predict the next character in a sequence.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text))) # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars)) # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model
model = Sequential([
    LSTM(128, input_shape=(X.shape[1], X.shape[2])),
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50): # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=1)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 21ms/step - loss: 2.9325
# Epoch 2/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.8958
# Epoch 3/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.8505
# Epoch 4/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7840
# Epoch 5/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7688
# Epoch 6/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7786
# Epoch 7/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7466
# Epoch 8/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7290
# Epoch 9/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7349
# Epoch 10/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7358
# Epoch 11/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7322
# Epoch 12/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7300
# Epoch 13/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7291
# Epoch 14/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7144
# Epoch 15/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7115
# Epoch 16/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7159
# Epoch 17/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7186
# Epoch 18/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7111
# Epoch 19/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7080
# Epoch 20/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7086
# Epoch 21/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7097
# Epoch 22/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7158
# Epoch 23/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7101
# Epoch 24/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.7052
# Epoch 25/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.7457
# Epoch 26/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.7573
# Epoch 27/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7211
# Epoch 28/100
# 5/5 [==============================] - 0s 26ms/step - loss: 2.7093
# Epoch 29/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7072
# Epoch 30/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7100
# Epoch 31/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7154
# Epoch 32/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7159
# Epoch 33/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7092
# Epoch 34/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7018
# Epoch 35/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6983
# Epoch 36/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7063
# Epoch 37/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7344
# Epoch 38/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7200
# Epoch 39/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6874
# Epoch 40/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6893
# Epoch 41/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.7085
# Epoch 42/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7107
# Epoch 43/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7219
# Epoch 44/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7102
# Epoch 45/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6941
# Epoch 46/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6934
# Epoch 47/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6953
# Epoch 48/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6994
# Epoch 49/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6964
# Epoch 50/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6985
# Epoch 51/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7037
# Epoch 52/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7017
# Epoch 53/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6964
# Epoch 54/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7006
# Epoch 55/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6960
# Epoch 56/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6977
# Epoch 57/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6967
# Epoch 58/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7031
# Epoch 59/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6996
# Epoch 60/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6924
# Epoch 61/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6895
# Epoch 62/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6838
# Epoch 63/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6890
# Epoch 64/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6887
# Epoch 65/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6871
# Epoch 66/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6843
# Epoch 67/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6901
# Epoch 68/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6871
# Epoch 69/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6821
# Epoch 70/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6794
# Epoch 71/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6818
# Epoch 72/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6816
# Epoch 73/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6819
# Epoch 74/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6793
# Epoch 75/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6838
# Epoch 76/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6941
# Epoch 77/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6750
# Epoch 78/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6848
# Epoch 79/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6786
# Epoch 80/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6766
# Epoch 81/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6717
# Epoch 82/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6686
# Epoch 83/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6788
# Epoch 84/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6757
# Epoch 85/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6659
# Epoch 86/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6667
# Epoch 87/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6908
# Epoch 88/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6918
# Epoch 89/100
# 5/5 [==============================] - 0s 23ms/step - loss: 2.6639
# Epoch 90/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6606
# Epoch 91/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6577
# Epoch 92/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6594
# Epoch 93/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6830
# Epoch 94/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6627
# Epoch 95/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6501
# Epoch 96/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6435
# Epoch 97/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6722
# Epoch 98/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6797
# Epoch 99/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6458
# Epoch 100/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6346
# Seed:
# " imple text "
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# s

# %% [markdown]
# Here, we first convert our sample text into sequences of characters. Each sequence of characters (X) corresponds to a next character (y). The model is trained to predict y from X.
#
# After training, we take a random seed sequence and use the model to predict the next 50 characters. The output will show the initial seed and the generated text based on it.

# %% [markdown]
# # GRU (Gated Recurrent Unit) is a variation of LSTM. It has fewer parameters than LSTM, as it lacks an output gate.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, GRU  # Note the change here
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model using GRU
model = Sequential([
    GRU(32, input_shape=(seq_length, 1)),  # Note the change here
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# Epoch 1/100
# 4/4 [==============================] - 1s 85ms/step - loss: 0.7084
# Epoch 2/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5792
# Epoch 3/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4603
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3705
# Epoch 5/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2976
# Epoch 6/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2388
# Epoch 7/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2052
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1834
# Epoch 9/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1728
# Epoch 10/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1752
# Epoch 11/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1740
# Epoch 12/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1744
# Epoch 13/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1710
# Epoch 14/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1660
# Epoch 15/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1604
# Epoch 16/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1582
# Epoch 17/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1567
# Epoch 18/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1565
# Epoch 19/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1556
# Epoch 20/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1539
# Epoch 21/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1514
# Epoch 22/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1490
# Epoch 23/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1476
# Epoch 24/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1462
# Epoch 25/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1448
# Epoch 26/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1436
# Epoch 27/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1423
# Epoch 28/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1413
# Epoch 29/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1396
# Epoch 30/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1385
# Epoch 31/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1382
# Epoch 32/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1368
# Epoch 33/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1357
# Epoch 34/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1345
# Epoch 35/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1332
# Epoch 36/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1316
# Epoch 37/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1312
# Epoch 38/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1299
# Epoch 39/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1282
# Epoch 40/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1262
# Epoch 41/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1249
# Epoch 42/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1238
# Epoch 43/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1229
# Epoch 44/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1216
# Epoch 45/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1201
# Epoch 46/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1192
# Epoch 47/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1177
# Epoch 48/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1166
# Epoch 49/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1162
# Epoch 50/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1162
# Epoch 51/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1144
# Epoch 52/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1125
# Epoch 53/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1116
# Epoch 54/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1100
# Epoch 55/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1090
# Epoch 56/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1082
# Epoch 57/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1082
# Epoch 58/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1075
# Epoch 59/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1072
# Epoch 60/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1056
# Epoch 61/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1042
# Epoch 62/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1037
# Epoch 63/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1027
# Epoch 64/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1018
# Epoch 65/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1000
# Epoch 66/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0999
# Epoch 67/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0975
# Epoch 68/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0958
# Epoch 69/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0952
# Epoch 70/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0929
# Epoch 71/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0933
# Epoch 72/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0929
# Epoch 73/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0892
# Epoch 74/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0889
# Epoch 75/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0911
# Epoch 76/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0892
# Epoch 77/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0862
# Epoch 78/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0849
# Epoch 79/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0842
# Epoch 80/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0820
# Epoch 81/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0811
# Epoch 82/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0833
# Epoch 83/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0809
# Epoch 84/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0792
# Epoch 85/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0776
# Epoch 86/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0753
# Epoch 87/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0780
# Epoch 88/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0759
# Epoch 89/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0747
# Epoch 90/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0713
# Epoch 91/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0725
# Epoch 92/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0739
# Epoch 93/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0716
# Epoch 94/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0683
# Epoch 95/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0681
# Epoch 96/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0667
# Epoch 97/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0680
# Epoch 98/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0661
# Epoch 99/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0659
# Epoch 100/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0662
# 1/1 [==============================] - 0s 198ms/step - loss: 0.7538
# Test Loss: 0.7537885904312134
# 1/1 [==============================] - 0s 156ms/step

# %% [markdown]
# # GRU on Text

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense  # Import GRU instead of LSTM

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text)))  # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars))  # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model using GRU
model = Sequential([
    GRU(128, input_shape=(X.shape[1], X.shape[2])),  # Change LSTM to GRU here
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50):  # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 21ms/step - loss: 2.9359
# Epoch 2/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.9084
# Epoch 3/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.8847
# Epoch 4/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.8564
# Epoch 5/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.8244
# Epoch 6/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7975
# Epoch 7/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7674
# Epoch 8/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7441
# Epoch 9/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7293
# Epoch 10/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7405
# Epoch 11/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7347
# Epoch 12/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7191
# Epoch 13/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7099
# Epoch 14/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7160
# Epoch 15/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7020
# Epoch 16/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7069
# Epoch 17/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7065
# Epoch 18/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7060
# Epoch 19/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7039
# Epoch 20/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7015
# Epoch 21/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6925
# Epoch 22/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7044
# Epoch 23/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7117
# Epoch 24/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.7036
# Epoch 25/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6998
# Epoch 26/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6989
# Epoch 27/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6891
# Epoch 28/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6976
# Epoch 29/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.7057
# Epoch 30/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.7300
# Epoch 31/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6949
# Epoch 32/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6891
# Epoch 33/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6928
# Epoch 34/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6956
# Epoch 35/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6945
# Epoch 36/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6951
# Epoch 37/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6883
# Epoch 38/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6880
# Epoch 39/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6807
# Epoch 40/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6787
# Epoch 41/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6913
# Epoch 42/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6819
# Epoch 43/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6861
# Epoch 44/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6889
# Epoch 45/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6910
# Epoch 46/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6909
# Epoch 47/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6835
# Epoch 48/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6774
# Epoch 49/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6724
# Epoch 50/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6640
# Epoch 51/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6764
# Epoch 52/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6978
# Epoch 53/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6896
# Epoch 54/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6722
# Epoch 55/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6511
# Epoch 56/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6547
# Epoch 57/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6486
# Epoch 58/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6521
# Epoch 59/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.6479
# Epoch 60/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6413
# Epoch 61/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6344
# Epoch 62/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6271
# Epoch 63/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6229
# Epoch 64/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6159
# Epoch 65/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6135
# Epoch 66/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.6093
# Epoch 67/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.5989
# Epoch 68/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.5882
# Epoch 69/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.5728
# Epoch 70/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.5594
# Epoch 71/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.5444
# Epoch 72/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.5533
# Epoch 73/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.5269
# Epoch 74/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.5022
# Epoch 75/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.5168
# Epoch 76/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.4953
# Epoch 77/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.4566
# Epoch 78/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.4434
# Epoch 79/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.4310
# Epoch 80/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.4107
# Epoch 81/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.3744
# Epoch 82/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.3318
# Epoch 83/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.2983
# Epoch 84/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.2923
# Epoch 85/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.2760
# Epoch 86/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.2841
# Epoch 87/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.2748
# Epoch 88/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.2167
# Epoch 89/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.2040
# Epoch 90/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.1660
# Epoch 91/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.1316
# Epoch 92/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0850
# Epoch 93/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0829
# Epoch 94/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.0700
# Epoch 95/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0110
# Epoch 96/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0056
# Epoch 97/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.0008
# Epoch 98/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.9875
# Epoch 99/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9716
# Epoch 100/100
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9042
# Seed:
# " s a simple "
#   ohi sn    ohr ne  tp rl   ohp sn   ohir n  thp
