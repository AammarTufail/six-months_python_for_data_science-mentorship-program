# %% [markdown]
# # RNN (Recurent Neural Network) - LSTM (Long Short Term Memory) - GRU (Gated Recurent Unit)

# %% [markdown]
# # RNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN
from tensorflow.keras.models import Sequential
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Generate example data
X = np.random.rand(100, 10, 1)
y = np.random.randint(0, 2, size=(100,))

# %%
X.shape, y.shape
# Out:
# ((100, 10, 1), (100,))

# %%
# Define the model
model = Sequential([
    SimpleRNN(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X, y, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# Epoch 1/10
# 2024-01-30 17:53:37.865761: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 1s 103ms/step - loss: 0.6908 - accuracy: 0.5500
# Epoch 2/10
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6726 - accuracy: 0.6000
# Epoch 3/10
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6677 - accuracy: 0.6100
# Epoch 4/10
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6664 - accuracy: 0.5900
# Epoch 5/10
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6669 - accuracy: 0.5800
# Epoch 6/10
# 4/4 [==============================] - 0s 60ms/step - loss: 0.6655 - accuracy: 0.5800
# Epoch 7/10
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6654 - accuracy: 0.5900
# Epoch 8/10
# 4/4 [==============================] - 0s 68ms/step - loss: 0.6621 - accuracy: 0.6100
# Epoch 9/10
# 4/4 [==============================] - 0s 65ms/step - loss: 0.6575 - accuracy: 0.6200
# Epoch 10/10
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6539 - accuracy: 0.6200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6523 - accuracy: 0.5938
# 2024-01-30 17:53:40.917692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6544 - accuracy: 0.6600
# Test Loss: 0.6544315218925476
# Test Accuracy: 0.6600000262260437

# %% [markdown]
# # LSTM (Long Short Term Memory) is a special kind of RNN, capable of learning long-term dependencies.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))
df.head()
# Out:
#             value
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %%
# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model
model = Sequential([
    LSTM(32, input_shape=(seq_length, 1)),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2024-01-30 17:53:41.749596: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:53:41.872554: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/4 [======>.......................] - ETA: 2s - loss: 1.2815
# 2024-01-30 17:53:41.974922: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 1s 31ms/step - loss: 1.0633
# Epoch 2/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8939
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7617
# Epoch 4/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6407
# Epoch 5/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5342
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4376
# Epoch 7/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3520
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2893
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2342
# Epoch 10/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1964
# Epoch 11/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1855
# Epoch 12/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1889
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1873
# Epoch 14/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1838
# Epoch 15/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1802
# Epoch 16/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1773
# Epoch 17/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1753
# Epoch 18/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1733
# Epoch 19/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1727
# Epoch 20/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1720
# Epoch 21/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1707
# Epoch 22/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1690
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1674
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1658
# Epoch 25/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1652
# Epoch 26/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1641
# Epoch 27/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1631
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1618
# Epoch 29/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1602
# Epoch 30/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1587
# Epoch 31/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1574
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1571
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1556
# Epoch 34/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1540
# Epoch 35/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1531
# Epoch 36/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1522
# Epoch 37/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1513
# Epoch 38/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1502
# Epoch 39/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1494
# Epoch 40/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1483
# Epoch 41/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1475
# Epoch 42/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1469
# Epoch 43/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1462
# Epoch 44/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1442
# Epoch 45/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1445
# Epoch 46/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1428
# Epoch 47/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1411
# Epoch 48/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1396
# Epoch 49/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1403
# Epoch 50/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1388
# Epoch 51/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1380
# Epoch 52/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1373
# Epoch 53/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1353
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1326
# Epoch 55/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1315
# Epoch 56/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1337
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1334
# Epoch 58/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1274
# Epoch 59/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1240
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1251
# Epoch 61/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1238
# Epoch 62/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1222
# Epoch 63/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1196
# Epoch 64/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1188
# Epoch 65/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1162
# Epoch 66/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1142
# Epoch 67/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1138
# Epoch 68/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1124
# Epoch 69/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1089
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1069
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1050
# Epoch 72/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1021
# Epoch 73/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1003
# Epoch 74/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0978
# Epoch 75/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0949
# Epoch 76/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0942
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0927
# Epoch 78/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0887
# Epoch 79/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0847
# Epoch 80/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0833
# Epoch 81/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0812
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0801
# Epoch 83/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0748
# Epoch 84/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0735
# Epoch 85/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0679
# Epoch 86/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0612
# Epoch 87/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0598
# Epoch 88/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0575
# Epoch 89/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0551
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0565
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0566
# Epoch 92/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0533
# Epoch 93/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0492
# Epoch 94/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0535
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0463
# Epoch 96/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0457
# Epoch 97/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0432
# Epoch 98/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0458
# Epoch 99/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0440
# Epoch 100/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0439
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x2cd4be310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 225ms/step - loss: 1.2701
# 2024-01-30 17:53:47.258391: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:53:47.305918: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Test Loss: 1.2700608968734741
# 1/1 [==============================] - 0s 198ms/step
# 2024-01-30 17:53:47.494242: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:53:47.536413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# # let's build a simple RNN-based character-level text generator using a sample text. We'll use a sequence-to-sequence prediction approach to predict the next character in a sequence.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text))) # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars)) # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model
model = Sequential([
    LSTM(128, input_shape=(X.shape[1], X.shape[2])),
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50): # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=1)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 2024-01-30 17:53:48.270880: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:53:48.387898: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 4/5 [=======================>......] - ETA: 0s - loss: 2.9357
# 2024-01-30 17:53:48.486946: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 5/5 [==============================] - 1s 26ms/step - loss: 2.9364
# Epoch 2/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.9028
# Epoch 3/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.8797
# Epoch 4/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.8553
# Epoch 5/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.8200
# Epoch 6/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7659
# Epoch 7/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7474
# Epoch 8/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7499
# Epoch 9/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7411
# Epoch 10/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7398
# Epoch 11/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7451
# Epoch 12/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7296
# Epoch 13/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7123
# Epoch 14/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7500
# Epoch 15/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.8009
# Epoch 16/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7346
# Epoch 17/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7003
# Epoch 18/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7113
# Epoch 19/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.7083
# Epoch 20/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.7062
# Epoch 21/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7054
# Epoch 22/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7125
# Epoch 23/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7264
# Epoch 24/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7168
# Epoch 25/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7076
# Epoch 26/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7055
# Epoch 27/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7031
# Epoch 28/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7067
# Epoch 29/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7053
# Epoch 30/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7078
# Epoch 31/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7045
# Epoch 32/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7040
# Epoch 33/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7159
# Epoch 34/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7151
# Epoch 35/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7062
# Epoch 36/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6990
# Epoch 37/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7001
# Epoch 38/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7052
# Epoch 39/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7021
# Epoch 40/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6991
# Epoch 41/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.6973
# Epoch 42/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6926
# Epoch 43/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6935
# Epoch 44/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6979
# Epoch 45/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6957
# Epoch 46/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7011
# Epoch 47/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6934
# Epoch 48/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6966
# Epoch 49/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6992
# Epoch 50/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7005
# Epoch 51/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7003
# Epoch 52/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6913
# Epoch 53/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7018
# Epoch 54/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7011
# Epoch 55/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6861
# Epoch 56/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6894
# Epoch 57/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6907
# Epoch 58/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6855
# Epoch 59/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7101
# Epoch 60/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7374
# Epoch 61/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7082
# Epoch 62/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6812
# Epoch 63/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6834
# Epoch 64/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6806
# Epoch 65/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6811
# Epoch 66/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6858
# Epoch 67/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6831
# Epoch 68/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6804
# Epoch 69/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6853
# Epoch 70/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6860
# Epoch 71/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6836
# Epoch 72/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6753
# Epoch 73/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6674
# Epoch 74/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6656
# Epoch 75/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6738
# Epoch 76/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6771
# Epoch 77/100
# 5/5 [==============================] - 0s 19ms/step - loss: 2.6783
# Epoch 78/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6847
# Epoch 79/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7016
# Epoch 80/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6795
# Epoch 81/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6455
# Epoch 82/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6946
# Epoch 83/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6589
# Epoch 84/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6580
# Epoch 85/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6654
# Epoch 86/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6663
# Epoch 87/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6636
# Epoch 88/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6496
# Epoch 89/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6504
# Epoch 90/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6437
# Epoch 91/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6458
# Epoch 92/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6616
# Epoch 93/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6599
# Epoch 94/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6368
# Epoch 95/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6393
# Epoch 96/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6294
# Epoch 97/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6274
# Epoch 98/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6220
# Epoch 99/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6206
# Epoch 100/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6091
# Seed:
# " ple for rn "
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2024-01-30 17:53:57.171003: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:53:57.213225: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step

# %% [markdown]
# Here, we first convert our sample text into sequences of characters. Each sequence of characters (X) corresponds to a next character (y). The model is trained to predict y from X.
#
# After training, we take a random seed sequence and use the model to predict the next 50 characters. The output will show the initial seed and the generated text based on it.

# %% [markdown]
# # GRU (Gated Recurrent Unit) is a variation of LSTM. It has fewer parameters than LSTM, as it lacks an output gate.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, GRU  # Note the change here
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model using GRU
model = Sequential([
    GRU(32, input_shape=(seq_length, 1)),  # Note the change here
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2024-01-30 17:53:59.818129: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:53:59.945438: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 1s 28ms/step - loss: 0.8938
# Epoch 2/100
# 2024-01-30 17:54:00.035844: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7607
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6462
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5559
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4718
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4045
# Epoch 7/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3452
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2899
# Epoch 9/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2522
# Epoch 10/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2177
# Epoch 11/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1991
# Epoch 12/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1870
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1835
# Epoch 14/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1831
# Epoch 15/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1804
# Epoch 16/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1761
# Epoch 17/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1731
# Epoch 18/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1706
# Epoch 19/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1682
# Epoch 20/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1657
# Epoch 21/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1635
# Epoch 22/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1623
# Epoch 23/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1601
# Epoch 24/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1584
# Epoch 25/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1558
# Epoch 26/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1537
# Epoch 27/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1521
# Epoch 28/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1500
# Epoch 29/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1482
# Epoch 30/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1465
# Epoch 31/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1448
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1428
# Epoch 33/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1408
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1396
# Epoch 35/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1373
# Epoch 36/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1347
# Epoch 37/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1325
# Epoch 38/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1302
# Epoch 39/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1287
# Epoch 40/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1259
# Epoch 41/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1248
# Epoch 42/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1221
# Epoch 43/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1204
# Epoch 44/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1184
# Epoch 45/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1178
# Epoch 46/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1173
# Epoch 47/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1143
# Epoch 48/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1118
# Epoch 49/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1115
# Epoch 50/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1096
# Epoch 51/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1081
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1061
# Epoch 53/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1049
# Epoch 54/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1040
# Epoch 55/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1023
# Epoch 56/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1023
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1017
# Epoch 58/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0989
# Epoch 59/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0972
# Epoch 60/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0964
# Epoch 61/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0988
# Epoch 62/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0953
# Epoch 63/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0934
# Epoch 64/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0917
# Epoch 65/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0921
# Epoch 66/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0892
# Epoch 67/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0897
# Epoch 68/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0884
# Epoch 69/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0863
# Epoch 70/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0866
# Epoch 71/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0846
# Epoch 72/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0837
# Epoch 73/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0823
# Epoch 74/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0814
# Epoch 75/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0804
# Epoch 76/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0806
# Epoch 77/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0788
# Epoch 78/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0810
# Epoch 79/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0785
# Epoch 80/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0759
# Epoch 81/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0753
# Epoch 82/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0724
# Epoch 83/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0737
# Epoch 84/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0735
# Epoch 85/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0699
# Epoch 86/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0678
# Epoch 87/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0677
# Epoch 88/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0682
# Epoch 89/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0649
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0680
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0657
# Epoch 92/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0609
# Epoch 93/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0616
# Epoch 94/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0590
# Epoch 95/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0581
# Epoch 96/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0572
# Epoch 97/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0561
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0553
# Epoch 99/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0552
# Epoch 100/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0542
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_test_function.<locals>.test_function at 0x2a14a8940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 206ms/step - loss: 0.8650
# 2024-01-30 17:54:05.018968: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:54:05.062488: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Test Loss: 0.8650076389312744
# 1/1 [==============================] - 0s 168ms/step
# 2024-01-30 17:54:05.231988: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:54:05.269903: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# # GRU on Text

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense  # Import GRU instead of LSTM

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text)))  # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars))  # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model using GRU
model = Sequential([
    GRU(128, input_shape=(X.shape[1], X.shape[2])),  # Change LSTM to GRU here
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50):  # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 2024-01-30 17:54:06.072400: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:54:06.192089: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:54:06.444359: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 5/5 [==============================] - 3s 268ms/step - loss: 2.9497
# Epoch 2/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.9238
# Epoch 3/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.9022
# Epoch 4/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.8803
# Epoch 5/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.8640
# Epoch 6/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.8346
# Epoch 7/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.8050
# Epoch 8/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7780
# Epoch 9/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7530
# Epoch 10/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7411
# Epoch 11/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7560
# Epoch 12/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7313
# Epoch 13/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7236
# Epoch 14/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7275
# Epoch 15/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7409
# Epoch 16/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.7311
# Epoch 17/100
# 5/5 [==============================] - 0s 26ms/step - loss: 2.7234
# Epoch 18/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7231
# Epoch 19/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7159
# Epoch 20/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7327
# Epoch 21/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7186
# Epoch 22/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7119
# Epoch 23/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7100
# Epoch 24/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7067
# Epoch 25/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7159
# Epoch 26/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7117
# Epoch 27/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.7085
# Epoch 28/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.7084
# Epoch 29/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7105
# Epoch 30/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7167
# Epoch 31/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.7159
# Epoch 32/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7113
# Epoch 33/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.7043
# Epoch 34/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6969
# Epoch 35/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6931
# Epoch 36/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6921
# Epoch 37/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6908
# Epoch 38/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.6850
# Epoch 39/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6852
# Epoch 40/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6880
# Epoch 41/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6898
# Epoch 42/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6814
# Epoch 43/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6785
# Epoch 44/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6712
# Epoch 45/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6785
# Epoch 46/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6765
# Epoch 47/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6759
# Epoch 48/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6697
# Epoch 49/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6702
# Epoch 50/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6662
# Epoch 51/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6579
# Epoch 52/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6521
# Epoch 53/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6486
# Epoch 54/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6298
# Epoch 55/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6345
# Epoch 56/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6240
# Epoch 57/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6079
# Epoch 58/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6078
# Epoch 59/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.6111
# Epoch 60/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.5942
# Epoch 61/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.5863
# Epoch 62/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.5655
# Epoch 63/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.5587
# Epoch 64/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.5236
# Epoch 65/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.4883
# Epoch 66/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.4844
# Epoch 67/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.4759
# Epoch 68/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.4526
# Epoch 69/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.4378
# Epoch 70/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3901
# Epoch 71/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.4009
# Epoch 72/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3812
# Epoch 73/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3722
# Epoch 74/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.3284
# Epoch 75/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3563
# Epoch 76/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2960
# Epoch 77/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2634
# Epoch 78/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.2703
# Epoch 79/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2349
# Epoch 80/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2072
# Epoch 81/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2001
# Epoch 82/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1861
# Epoch 83/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2187
# Epoch 84/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1432
# Epoch 85/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.3055
# Epoch 86/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1316
# Epoch 87/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1128
# Epoch 88/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.1097
# Epoch 89/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0797
# Epoch 90/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0886
# Epoch 91/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0381
# Epoch 92/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0826
# Epoch 93/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0494
# Epoch 94/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0974
# Epoch 95/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9922
# Epoch 96/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.9792
# Epoch 97/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.9601
# Epoch 98/100
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9083
# Epoch 99/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.8988
# Epoch 100/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.8747
# Seed:
# " s a simple "
# 2024-01-30 17:54:16.857249: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-30 17:54:16.895086: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  thi le    iiillee  thille   tiille   tiille   ti
