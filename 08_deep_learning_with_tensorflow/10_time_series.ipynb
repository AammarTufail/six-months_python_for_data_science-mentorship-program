# %% [markdown]
# # Time series analysis on the data International Airline passengers from 1940 to 1960

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# data fetch from github
df = pd.read_csv("AirPassengers.csv")
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.shape
# Out:
# (144, 2)

# %%
# plot this data to see trends and seasonality with seaborn
sns.lineplot(x="Month", y="#Passengers", data=df)
# Out:
# <Axes: xlabel='Month', ylabel='#Passengers'>

# %%
# decompose the data into trend, seasonality and residuals
decompose = seasonal_decompose(df["#Passengers"], model="multiplicative", period=12)
decompose.plot()

# %%
decompose.seasonal.plot()
# Out:
# <Axes: >

# %%
trend = decompose.trend
seasonal = decompose.seasonal
residual = decompose.resid

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.metrics import RootMeanSquaredError

# split the data into training and testing sets
train_size = int(len(df) * 0.8)
train = df[:train_size]
test = df[train_size:]

# define the number of lagged time steps to use as input features
n_lags = 12

# create the input and output data for the neural network
X_train = np.array([train["#Passengers"].values[i:i+n_lags] for i in range(len(train)-n_lags)])
y_train = np.array(train["#Passengers"].values[n_lags:])
X_test = np.array([test["#Passengers"].values[i:i+n_lags] for i in range(len(test)-n_lags)])
y_test = np.array(test["#Passengers"].values[n_lags:])

# create the neural network model
model = Sequential()
model.add(Dense(10, input_dim=n_lags, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam", metrics=[RootMeanSquaredError()])

# train the neural network model
model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)

# make predictions on the testing set using the trained model
predictions = model.predict(X_test)

# plot the actual and predicted values
plt.plot(test.index[-len(predictions):], test["#Passengers"].values[-len(predictions):], label="actual")
plt.plot(test.index[-len(predictions):], predictions, label="predicted")
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 14ms/step - loss: 49010.8203 - root_mean_squared_error: 221.3839
# Epoch 2/100
# 11/11 [==============================] - 0s 9ms/step - loss: 21561.6328 - root_mean_squared_error: 146.8388
# Epoch 3/100
# 11/11 [==============================] - 0s 9ms/step - loss: 7795.0581 - root_mean_squared_error: 88.2896
# Epoch 4/100
# 11/11 [==============================] - 0s 8ms/step - loss: 3050.1211 - root_mean_squared_error: 55.2279
# Epoch 5/100
# 11/11 [==============================] - 0s 9ms/step - loss: 2326.6174 - root_mean_squared_error: 48.2350
# Epoch 6/100
# 11/11 [==============================] - 0s 11ms/step - loss: 2399.3577 - root_mean_squared_error: 48.9832
# Epoch 7/100
# 11/11 [==============================] - 0s 10ms/step - loss: 2364.5801 - root_mean_squared_error: 48.6269
# Epoch 8/100
# 11/11 [==============================] - 0s 12ms/step - loss: 2280.0027 - root_mean_squared_error: 47.7494
# Epoch 9/100
# 11/11 [==============================] - 0s 8ms/step - loss: 2266.3328 - root_mean_squared_error: 47.6060
# Epoch 10/100
# 11/11 [==============================] - 0s 9ms/step - loss: 2211.4077 - root_mean_squared_error: 47.0256
# Epoch 11/100
# 11/11 [==============================] - 0s 8ms/step - loss: 2170.8796 - root_mean_squared_error: 46.5927
# Epoch 12/100
# 11/11 [==============================] - 0s 9ms/step - loss: 2126.1919 - root_mean_squared_error: 46.1106
# Epoch 13/100
# 11/11 [==============================] - 0s 8ms/step - loss: 2068.0852 - root_mean_squared_error: 45.4762
# Epoch 14/100
# 11/11 [==============================] - 0s 9ms/step - loss: 2029.4089 - root_mean_squared_error: 45.0490
# Epoch 15/100
# 11/11 [==============================] - 0s 11ms/step - loss: 1983.9735 - root_mean_squared_error: 44.5418
# Epoch 16/100
# 11/11 [==============================] - 0s 9ms/step - loss: 1935.7961 - root_mean_squared_error: 43.9977
# Epoch 17/100
# 11/11 [==============================] - 0s 12ms/step - loss: 1893.2850 - root_mean_squared_error: 43.5119
# Epoch 18/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1834.3533 - root_mean_squared_error: 42.8293
# Epoch 19/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1783.1201 - root_mean_squared_error: 42.2270
# Epoch 20/100
# 11/11 [==============================] - 0s 9ms/step - loss: 1790.4399 - root_mean_squared_error: 42.3136
# Epoch 21/100
# 11/11 [==============================] - 0s 9ms/step - loss: 1751.2225 - root_mean_squared_error: 41.8476
# Epoch 22/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1668.9293 - root_mean_squared_error: 40.8525
# Epoch 23/100
# 11/11 [==============================] - 0s 7ms/step - loss: 1613.1448 - root_mean_squared_error: 40.1640
# Epoch 24/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1554.8204 - root_mean_squared_error: 39.4312
# Epoch 25/100
# 11/11 [==============================] - 0s 9ms/step - loss: 1525.9911 - root_mean_squared_error: 39.0639
# Epoch 26/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1465.1755 - root_mean_squared_error: 38.2776
# Epoch 27/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1416.0087 - root_mean_squared_error: 37.6299
# Epoch 28/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1368.7264 - root_mean_squared_error: 36.9963
# Epoch 29/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1336.8918 - root_mean_squared_error: 36.5635
# Epoch 30/100
# 11/11 [==============================] - 0s 10ms/step - loss: 1296.8959 - root_mean_squared_error: 36.0124
# Epoch 31/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1254.9917 - root_mean_squared_error: 35.4259
# Epoch 32/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1207.1572 - root_mean_squared_error: 34.7442
# Epoch 33/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1184.2406 - root_mean_squared_error: 34.4128
# Epoch 34/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1129.6520 - root_mean_squared_error: 33.6103
# Epoch 35/100
# 11/11 [==============================] - 0s 11ms/step - loss: 1091.3389 - root_mean_squared_error: 33.0354
# Epoch 36/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1059.1227 - root_mean_squared_error: 32.5442
# Epoch 37/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1028.9546 - root_mean_squared_error: 32.0773
# Epoch 38/100
# 11/11 [==============================] - 0s 9ms/step - loss: 994.2087 - root_mean_squared_error: 31.5311
# Epoch 39/100
# 11/11 [==============================] - 0s 8ms/step - loss: 968.4326 - root_mean_squared_error: 31.1196
# Epoch 40/100
# 11/11 [==============================] - 0s 9ms/step - loss: 918.1363 - root_mean_squared_error: 30.3008
# Epoch 41/100
# 11/11 [==============================] - 0s 8ms/step - loss: 873.2212 - root_mean_squared_error: 29.5503
# Epoch 42/100
# 11/11 [==============================] - 0s 9ms/step - loss: 851.9469 - root_mean_squared_error: 29.1881
# Epoch 43/100
# 11/11 [==============================] - 0s 8ms/step - loss: 829.0650 - root_mean_squared_error: 28.7935
# Epoch 44/100
# 11/11 [==============================] - 0s 9ms/step - loss: 811.0178 - root_mean_squared_error: 28.4784
# Epoch 45/100
# 11/11 [==============================] - 0s 8ms/step - loss: 761.7221 - root_mean_squared_error: 27.5993
# Epoch 46/100
# 11/11 [==============================] - 0s 9ms/step - loss: 743.2488 - root_mean_squared_error: 27.2626
# Epoch 47/100
# 11/11 [==============================] - 0s 8ms/step - loss: 714.5667 - root_mean_squared_error: 26.7314
# Epoch 48/100
# 11/11 [==============================] - 0s 8ms/step - loss: 690.7484 - root_mean_squared_error: 26.2821
# Epoch 49/100
# 11/11 [==============================] - 0s 8ms/step - loss: 665.6915 - root_mean_squared_error: 25.8010
# Epoch 50/100
# 11/11 [==============================] - 0s 9ms/step - loss: 649.8672 - root_mean_squared_error: 25.4925
# Epoch 51/100
# 11/11 [==============================] - 0s 8ms/step - loss: 637.0546 - root_mean_squared_error: 25.2399
# Epoch 52/100
# 11/11 [==============================] - 0s 9ms/step - loss: 642.7479 - root_mean_squared_error: 25.3525
# Epoch 53/100
# 11/11 [==============================] - 0s 8ms/step - loss: 608.7143 - root_mean_squared_error: 24.6721
# Epoch 54/100
# 11/11 [==============================] - 0s 18ms/step - loss: 573.5771 - root_mean_squared_error: 23.9495
# Epoch 55/100
# 11/11 [==============================] - 0s 8ms/step - loss: 569.2021 - root_mean_squared_error: 23.8580
# Epoch 56/100
# 11/11 [==============================] - 0s 8ms/step - loss: 548.7058 - root_mean_squared_error: 23.4245
# Epoch 57/100
# 11/11 [==============================] - 0s 9ms/step - loss: 512.8995 - root_mean_squared_error: 22.6473
# Epoch 58/100
# 11/11 [==============================] - 0s 9ms/step - loss: 515.0874 - root_mean_squared_error: 22.6955
# Epoch 59/100
# 11/11 [==============================] - 0s 10ms/step - loss: 506.9514 - root_mean_squared_error: 22.5156
# Epoch 60/100
# 11/11 [==============================] - 0s 8ms/step - loss: 516.5789 - root_mean_squared_error: 22.7284
# Epoch 61/100
# 11/11 [==============================] - 0s 9ms/step - loss: 487.2296 - root_mean_squared_error: 22.0733
# Epoch 62/100
# 11/11 [==============================] - 0s 8ms/step - loss: 468.6280 - root_mean_squared_error: 21.6478
# Epoch 63/100
# 11/11 [==============================] - 0s 9ms/step - loss: 463.7853 - root_mean_squared_error: 21.5357
# Epoch 64/100
# 11/11 [==============================] - 0s 9ms/step - loss: 447.2336 - root_mean_squared_error: 21.1479
# Epoch 65/100
# 11/11 [==============================] - 0s 9ms/step - loss: 435.8645 - root_mean_squared_error: 20.8774
# Epoch 66/100
# 11/11 [==============================] - 0s 9ms/step - loss: 428.4915 - root_mean_squared_error: 20.7000
# Epoch 67/100
# 11/11 [==============================] - 0s 14ms/step - loss: 423.0725 - root_mean_squared_error: 20.5687
# Epoch 68/100
# 11/11 [==============================] - 0s 9ms/step - loss: 417.6550 - root_mean_squared_error: 20.4366
# Epoch 69/100
# 11/11 [==============================] - 0s 9ms/step - loss: 423.2715 - root_mean_squared_error: 20.5736
# Epoch 70/100
# 11/11 [==============================] - 0s 8ms/step - loss: 394.3334 - root_mean_squared_error: 19.8578
# Epoch 71/100
# 11/11 [==============================] - 0s 7ms/step - loss: 419.1246 - root_mean_squared_error: 20.4725
# Epoch 72/100
# 11/11 [==============================] - 0s 7ms/step - loss: 388.3712 - root_mean_squared_error: 19.7071
# Epoch 73/100
# 11/11 [==============================] - 0s 7ms/step - loss: 382.7863 - root_mean_squared_error: 19.5649
# Epoch 74/100
# 11/11 [==============================] - 0s 7ms/step - loss: 379.6078 - root_mean_squared_error: 19.4835
# Epoch 75/100
# 11/11 [==============================] - 0s 8ms/step - loss: 373.1403 - root_mean_squared_error: 19.3168
# Epoch 76/100
# 11/11 [==============================] - 0s 7ms/step - loss: 373.7984 - root_mean_squared_error: 19.3339
# Epoch 77/100
# 11/11 [==============================] - 0s 7ms/step - loss: 370.4454 - root_mean_squared_error: 19.2470
# Epoch 78/100
# 11/11 [==============================] - 0s 7ms/step - loss: 361.3213 - root_mean_squared_error: 19.0085
# Epoch 79/100
# 11/11 [==============================] - 0s 7ms/step - loss: 364.1945 - root_mean_squared_error: 19.0839
# Epoch 80/100
# 11/11 [==============================] - 0s 8ms/step - loss: 351.1375 - root_mean_squared_error: 18.7387
# Epoch 81/100
# 11/11 [==============================] - 0s 7ms/step - loss: 363.2457 - root_mean_squared_error: 19.0590
# Epoch 82/100
# 11/11 [==============================] - 0s 10ms/step - loss: 348.8797 - root_mean_squared_error: 18.6783
# Epoch 83/100
# 11/11 [==============================] - 0s 7ms/step - loss: 350.8552 - root_mean_squared_error: 18.7311
# Epoch 84/100
# 11/11 [==============================] - 0s 7ms/step - loss: 353.4726 - root_mean_squared_error: 18.8009
# Epoch 85/100
# 11/11 [==============================] - 0s 8ms/step - loss: 339.8684 - root_mean_squared_error: 18.4355
# Epoch 86/100
# 11/11 [==============================] - 0s 8ms/step - loss: 345.7933 - root_mean_squared_error: 18.5955
# Epoch 87/100
# 11/11 [==============================] - 0s 7ms/step - loss: 337.6927 - root_mean_squared_error: 18.3764
# Epoch 88/100
# 11/11 [==============================] - 0s 11ms/step - loss: 336.7844 - root_mean_squared_error: 18.3517
# Epoch 89/100
# 11/11 [==============================] - 0s 9ms/step - loss: 350.5769 - root_mean_squared_error: 18.7237
# Epoch 90/100
# 11/11 [==============================] - 0s 9ms/step - loss: 332.6750 - root_mean_squared_error: 18.2394
# Epoch 91/100
# 11/11 [==============================] - 0s 8ms/step - loss: 351.2478 - root_mean_squared_error: 18.7416
# Epoch 92/100
# 11/11 [==============================] - 0s 9ms/step - loss: 336.4527 - root_mean_squared_error: 18.3426
# Epoch 93/100
# 11/11 [==============================] - 0s 9ms/step - loss: 326.5558 - root_mean_squared_error: 18.0709
# Epoch 94/100
# 11/11 [==============================] - 0s 9ms/step - loss: 324.4562 - root_mean_squared_error: 18.0127
# Epoch 95/100
# 11/11 [==============================] - 0s 14ms/step - loss: 340.0101 - root_mean_squared_error: 18.4394
# Epoch 96/100
# 11/11 [==============================] - 0s 9ms/step - loss: 323.0140 - root_mean_squared_error: 17.9726
# Epoch 97/100
# 11/11 [==============================] - 0s 12ms/step - loss: 318.3874 - root_mean_squared_error: 17.8434
# Epoch 98/100
# 11/11 [==============================] - 0s 9ms/step - loss: 324.1354 - root_mean_squared_error: 18.0038
# Epoch 99/100
# 11/11 [==============================] - 0s 9ms/step - loss: 314.3813 - root_mean_squared_error: 17.7308
# Epoch 100/100
# 11/11 [==============================] - 0s 8ms/step - loss: 319.5784 - root_mean_squared_error: 17.8768
# 1/1 [==============================] - 0s 37ms/step
